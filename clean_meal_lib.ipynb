# %%
import pandas as pd

# %%
df = pd.read_csv('all_calories_from_dynamic_links.csv')

# %%
df.head(5)
# Out:
#           Subcategory                   Food Serving Calories  \
# 0  Liquor & Cocktails         Absinthe (70%)  100 ml  443 Cal
# 1  Liquor & Cocktails         Amaretto (28%)  100 ml  318 Cal
# 2  Liquor & Cocktails          Baileys (17%)  100 ml  314 Cal
# 3  Liquor & Cocktails     Blue Curacao (21%)  100 ml  243 Cal
# 4  Liquor & Cocktails  Bourbon Whiskey (40%)  100 ml  248 Cal
#
#                                                URL
# 0  https://www.calories.info/food/liquor-cocktails
# 1  https://www.calories.info/food/liquor-cocktails
# 2  https://www.calories.info/food/liquor-cocktails
# 3  https://www.calories.info/food/liquor-cocktails
# 4  https://www.calories.info/food/liquor-cocktails

# %%
df = df.drop(columns=['URL'])

# %%
df.head(5)
# Out:
#           Subcategory                   Food Serving Calories
# 0  Liquor & Cocktails         Absinthe (70%)  100 ml  443 Cal
# 1  Liquor & Cocktails         Amaretto (28%)  100 ml  318 Cal
# 2  Liquor & Cocktails          Baileys (17%)  100 ml  314 Cal
# 3  Liquor & Cocktails     Blue Curacao (21%)  100 ml  243 Cal
# 4  Liquor & Cocktails  Bourbon Whiskey (40%)  100 ml  248 Cal

# %%
subcategories = df['Subcategory'].unique()

# %%
# Count them
num_subcategories = len(subcategories)

print(f"Number of subcategories: {num_subcategories}")
print("Subcategories:")
print(subcategories)
# Out:
# Number of subcategories: 40
# Subcategories:
# ['Liquor & Cocktails' 'Meat' 'Beer' 'Fruit' 'Pizza' 'Vegetables & Legumes'
#  'Beef & Veal' 'Bread, Bread Rolls & Pastries' 'Cakes & Pies' 'Cereal'
#  'Cheese' 'Chips, Popcorn & Snacks' 'Coffee' 'Cream Cheese'
#  'Desserts & Pudding' 'Fast Food & Burgers' 'Fish & Seafood'
#  'Flour, Grains & Baking Ingredients' 'Ham & Sausage'
#  'Herbs, Spices & Tea' 'Ice Cream' 'Juice & Soft Drinks' 'Meals & Dishes'
#  'Milk & Dairy Products' 'Mushrooms' 'Nuts & Seeds' 'Oils & Fats'
#  'Pasta & Noodles' 'Pork' 'Potatoes & Potato Products'
#  'Poultry, Chicken & Turkey' 'Rice & Rice Products' 'Salad'
#  'Sauces, Gravy, Dressing & Spreads' 'Supplements & Protein Powder'
#  'Sushi' 'Sweets: Chocolate, Cookies, Candy' 'Tofu & Vegan Products'
#  'Wine' 'Yogurt']

# %% [markdown]
# Remove unnecessary subcategories:['Liquor & Cocktails' 'Beer'
# 'Cereal'
#  'Cheese' 'Chips, Popcorn & Snacks' 'Coffee' 'Cream Cheese'
#  'Desserts & Pudding'
#  'Flour, Grains & Baking Ingredients' 'Ham & Sausage'
#  'Herbs, Spices & Tea' 'Ice Cream' 'Juice & Soft Drinks' 'Meals & Dishes'
# 'Mushrooms'  'Oils & Fats'
#  'Sauces, Gravy, Dressing & Spreads' 'Supplements & Protein Powder'
# 'Sweets: Chocolate, Cookies, Candy'
#  'Wine' ]

# %%
# Define subcategories to remove
subcategories_to_remove = [
    'Liquor & Cocktails', 'Beer', 'Cereal', 'Cheese', 'Chips, Popcorn & Snacks',
    'Coffee', 'Cream Cheese', 'Desserts & Pudding', 'Flour, Grains & Baking Ingredients',
    'Ham & Sausage', 'Herbs, Spices & Tea', 'Ice Cream', 'Juice & Soft Drinks',
    'Meals & Dishes', 'Mushrooms', 'Oils & Fats', 'Sauces, Gravy, Dressing & Spreads',
    'Supplements & Protein Powder', 'Sweets: Chocolate, Cookies, Candy', 'Wine'
]

# Drop rows where Subcategory is in the list
df = df[~df['Subcategory'].isin(subcategories_to_remove)]

# %%
df.head(5)
# Out:
#    Subcategory                          Food Serving Calories
# 32        Meat                     Alligator   100 g   97 Cal
# 33        Meat                          Beef   100 g  156 Cal
# 34        Meat                  Beef Bologna   100 g  299 Cal
# 35        Meat  Beef Fillet, Beef Tenderloin   100 g  121 Cal
# 36        Meat                    Beef Heart   100 g  105 Cal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 979 entries, 32 to 2011
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Subcategory  979 non-null    object
#  1   Food         979 non-null    object
#  2   Serving      979 non-null    object
#  3   Calories     979 non-null    object
# dtypes: object(4)
# memory usage: 38.2+ KB

# %%
df.shape
# Out:
# (979, 4)

# %%
sub_left = df['Subcategory'].unique()

# %%
sub_left
# Out:
# array(['Meat', 'Fruit', 'Pizza', 'Vegetables & Legumes', 'Beef & Veal',
#        'Bread, Bread Rolls & Pastries', 'Cakes & Pies',
#        'Fast Food & Burgers', 'Fish & Seafood', 'Milk & Dairy Products',
#        'Nuts & Seeds', 'Pasta & Noodles', 'Pork',
#        'Potatoes & Potato Products', 'Poultry, Chicken & Turkey',
#        'Rice & Rice Products', 'Salad', 'Sushi', 'Tofu & Vegan Products',
#        'Yogurt'], dtype=object)

# %%
df.to_csv('calories_library.csv', index=False)
